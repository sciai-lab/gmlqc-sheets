# %%
import pyscf

mol = pyscf.gto.Mole()
mol.atom = "H 0 0 0; F 0 0 1"
mol.basis = "6-31G*"
mol.build()

mf = pyscf.scf.RHF(mol)
mf.verbose = 9
mf.kernel()
# Out:
# ******** <class 'pyscf.scf.hf.RHF'> ********
# method = RHF
# initial guess = minao
# damping factor = 0
# level_shift factor = 0
# DIIS = <class 'pyscf.scf.diis.CDIIS'>
# diis_start_cycle = 1
# diis_space = 8
# diis_damp = 0
# SCF conv_tol = 1e-09
# SCF conv_tol_grad = None
# SCF max_cycles = 50
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /tmp/nix-shell.eTf0Z1/tmpehl02aft
# max_memory 4000 MB (current use 149 MB)
# Set gradient conv threshold to 3.16228e-05
# Initial guess from minao.
# Nelec from initial guess = 9.973278835750008
# E1 = -148.5175623697467  E_coul = 44.03544774020525
# init E= -99.7195197312615
# cond(S) = 23.63794702429976
#     CPU time for initialize scf      5.27 sec, wall time      0.20 sec
#   HOMO = -0.651821715837752  LUMO = 0.10201798620362
#   mo_energy =
# [-26.48758877  -1.74076347  -0.80105586  -0.65182172  -0.65182172
#    0.10201799   0.99111866   1.38825634   1.38825634   1.45521781
# ...
